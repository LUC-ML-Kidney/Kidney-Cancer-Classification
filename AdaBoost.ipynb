# %%
import pandas as pd

# %%
# load datasets
df = pd.read_csv('Data/merged_data.csv')

# %%
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sample  1025 non-null   str
#  1   cancer  1025 non-null   str
# dtypes: str(2)
# memory usage: 16.1 KB

# %%
# Out:
#            Ensembl_ID  TCGA-KN-8431-01A  TCGA-KN-8433-11A  TCGA-KN-8433-01A  \
# 0  ENSG00000000003.15          2.922369          5.082860          3.150982
# 1   ENSG00000000005.6          0.040121          1.430767          0.000000
# 2  ENSG00000000419.13          5.234570          4.708689          4.683680
# 3  ENSG00000000457.14          0.836086          1.613485          0.919607
# 4  ENSG00000000460.17          0.257011          0.456596          0.326882
#
#    TCGA-KO-8407-01A  TCGA-KL-8331-01A  TCGA-KL-8336-01A  TCGA-KM-8439-01A  \
# 0          3.515813          4.721969          3.356116          4.203961
# 1          0.363227          0.391878          0.110363          0.000000
# 2          5.020418          5.243284          4.274329          4.705160
# 3          0.969160          1.116431          1.315914          1.369606
# 4          0.437121          0.407298          0.614474          0.335026
#
#    TCGA-KO-8403-01A  TCGA-KL-8332-11A  ...  TCGA-5P-A9KE-01A  \
# ...

# %%
# Out:
#              sample                                  cancer
# 0  TCGA-UW-A72Q-01A  Renal cell carcinoma, chromophobe type
# 1  TCGA-KM-8442-01A  Renal cell carcinoma, chromophobe type
# 2  TCGA-KL-8328-01A  Renal cell carcinoma, chromophobe type
# 3  TCGA-KN-8430-11A  Renal cell carcinoma, chromophobe type
# 4  TCGA-KN-8430-01A  Renal cell carcinoma, chromophobe type
